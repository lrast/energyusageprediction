# %%
import pandas as pd

import lightgbm as lgb

# %%
import sys
sys.path.append('../')

from EnefitModels.src.features import load_data

data = load_data.load_processed_data('../data')

# %%
data.clients
# Out:
#        product_type  county  eic_count  installed_capacity  is_business  \
# 0                 1       0        108              952.89            0
# 1                 2       0         17              166.40            0
# 2                 3       0        688             7207.88            0
# 3                 0       0          5              400.00            1
# 4                 1       0         43             1411.00            1
# ...             ...     ...        ...                 ...          ...
# 41914             1      15         51              415.60            0
# 41915             3      15        161             2035.75            0
# 41916             0      15         15              620.00            1
# 41917             1      15         20              624.50            1
# 41918             3      15         55             2188.20            1
#
#              date  data_block_id
# 0      2021-09-01              2
# 1      2021-09-01              2
# ...

# %%
def make_regression_features(train, clients):
    pass
